# %% [markdown]
# # 4.소득소비 데이터 전처리

# %% [markdown]
# . 기준년, 분기, 상권코드 기준으로 주변 해당 상권 내 거주한 인구의 추정 소득금액
# . 지출 데이터는 해당 상권 내 상가를 분류(식료품, 생활용품 등)하고, 분류된 상가에서 발생한 카드 결제 금액을 합산하고 보정하여 계산

# %%
import pandas as pd
from scipy.spatial import distance
import numpy as np

# %%
df = pd.read_csv('./data/서울시 우리마을가게 상권분석서비스(상권-소득소비).csv', encoding='cp949')

# %% [markdown]
# ### 1. 2017년부터 2021년까지의 데이터를 가지고 있으므로 최종 데이터인 2021년 데이터 선택

# %%
### 4.1. 2017년부터 2021년까지의 데이터를 가지고 있으므로 최종 데이터인 2021년 데이터 선택  
df_1 = df.loc[df['기준_년_코드']==2021]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6520 entries, 0 to 6519
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   기준_년_코드       6520 non-null   int64
#  1   기준_분기_코드      6520 non-null   int64
#  2   상권_구분_코드      6520 non-null   object
#  3   상권_구분_코드_명    6520 non-null   object
#  4   상권_코드         6520 non-null   int64
#  5   상권_코드_명       6520 non-null   object
#  6   월_평균_소득_금액    6480 non-null   float64
#  7   소득_구간_코드      6480 non-null   float64
#  8   지출_총금액        6388 non-null   float64
#  9   식료품_지출_총금액    6388 non-null   float64
#  10  의류_신발_지출_총금액  6388 non-null   float64
#  11  생활용품_지출_총금액   6388 non-null   float64
#  12  의료비_지출_총금액    6388 non-null   float64
#  13  교통_지출_총금액     6388 non-null   float64
#  14  여가_지출_총금액     6388 non-null   float64
#  15  문화_지출_총금액     6388 non-null   float64
#  16  교육_지출_총금액     6388 non-null   float64
#  17  유흥_지출_총금액     6388 non-null   float64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 967.8+ KB

# %%
df_1.columns[6:]
# Out:
# Index(['월_평균_소득_금액', '소득_구간_코드', '지출_총금액', '식료품_지출_총금액', '의류_신발_지출_총금액',
#        '생활용품_지출_총금액', '의료비_지출_총금액', '교통_지출_총금액', '여가_지출_총금액', '문화_지출_총금액',
#        '교육_지출_총금액', '유흥_지출_총금액'],
#       dtype='object')

# %% [markdown]
# ### 2. 결측치 확인

# %% [markdown]
# . 데이터 확인 시 상권코드 기준으로 분기와 상관없이 데이터가 아예 존재하지 않음
# . 데이터 보간방법을 아래 두가지가 있음
# . 1. 데이터 삭제
# . 2. 지리적으로 가까운곳(유클리디안 거리로)의 값을 사용

# %%
df[df['월_평균_소득_금액'].isnull()].sort_values(by = ['상권_코드', '기준_분기_코드'])
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명  월_평균_소득_금액  \
# 31247     2017         1        A       골목상권  2110310  길음역 10번         NaN
# 31522     2017         1        A       골목상권  2110585    마포경찰서         NaN
# 16885     2019         2        A       골목상권  2110585    마포경찰서         NaN
# 29900     2017         2        A       골목상권  2110585    마포경찰서         NaN
# 15254     2019         3        A       골목상권  2110585    마포경찰서         NaN
# ...        ...       ...      ...        ...      ...      ...         ...
# 1606      2021         4        R       전통시장  2130308   청담삼익시장         NaN
# 8126      2020         4        R       전통시장  2130308   청담삼익시장         NaN
# 14646     2019         4        R       전통시장  2130308   청담삼익시장         NaN
# 21160     2018         4        R       전통시장  2130308   청담삼익시장         NaN
# 27666     2017         4        R       전통시장  2130308   청담삼익시장         NaN
#
#        소득_구간_코드       지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# 31247       NaN    7680530.0   2157906.0      929290.0     485936.0
# 31522       NaN  355124249.0  84163827.0    41482163.0   23846320.0
# 16885       NaN  199998259.0  45248746.0    23599180.0   13843089.0
# 29900       NaN  163139030.0  39677915.0    19078310.0   10933538.0
# 15254       NaN  199998259.0  45248746.0    23599180.0   13843089.0
# ...         ...          ...         ...           ...          ...
# 1606        NaN   81671028.0  18684612.0    11309429.0    6514972.0
# 8126        NaN   81671028.0  18684612.0    11309429.0    6514972.0
# 14646       NaN   81671028.0  18684612.0    11309429.0    6514972.0
# 21160       NaN   81671028.0  18684612.0    11309429.0    6514972.0
# 27666       NaN   81671028.0  18684612.0    11309429.0    6514972.0
#
#        의료비_지출_총금액   교통_지출_총금액   여가_지출_총금액   문화_지출_총금액   교육_지출_총금액   유흥_지출_총금액
# 31247   1019206.0   1267932.0    255508.0    240810.0   1008780.0    315162.0
# 31522  40461022.0  62943987.0  12413333.0  10675759.0  65317271.0  13820567.0
# 16885  22159464.0  36666065.0   7066558.0   5880357.0  37526239.0   8008561.0
# 29900  19062630.0  28218214.0   5765732.0   5000894.0  29250365.0   6151432.0
# 15254  22159464.0  36666065.0   7066558.0   5880357.0  37526239.0   8008561.0
# ...           ...         ...         ...         ...         ...         ...
# 1606   10145059.0  15516256.0   5218093.0   2284347.0   8503220.0   3495040.0
# 8126   10145059.0  15516256.0   5218093.0   2284347.0   8503220.0   3495040.0
# 14646  10145059.0  15516256.0   5218093.0   2284347.0   8503220.0   3495040.0
# 21160  10145059.0  15516256.0   5218093.0   2284347.0   8503220.0   3495040.0
# 27666  10145059.0  15516256.0   5218093.0   2284347.0   8503220.0   3495040.0
#
# [174 rows x 18 columns]

# %%
df.loc[df['지출_총금액'].isnull(), '상권_코드'].unique()
# Out:
# array([2110108, 2110648, 2110674, 2110704, 2110705, 2110764, 2110806,
#        2111090, 2120060, 2120080, 2120098, 2120118, 2120218, 2130012,
#        2130039, 2130046, 2130088, 2130153, 2130154, 2130155, 2130164,
#        2130170, 2130176, 2130189, 2130196, 2130197, 2130205, 2130240,
#        2130280, 2130284, 2130304, 2130310, 1001496, 2130085, 2130250,
#        2130093, 2130184, 2110761, 2120023, 2120028, 2120029, 2120117,
#        2120129, 2130005, 2130007, 2130013, 2130016, 2130017, 2130021,
#        2130024, 2130048, 2130071, 2130079, 2130113, 2130121, 2130253,
#        2130263, 2130292, 2110793, 2120025])

# %%
a = df['지출_총금액'].isnull()
b = df['상권_코드']==2130007

df[a&b]
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  \
# 30650     2017         2        R       전통시장  2130007  광장시장(광장전통시장)
# 32274     2017         1        R       전통시장  2130007  광장시장(광장전통시장)
#
#        월_평균_소득_금액  소득_구간_코드  지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# 30650   3050107.0       7.0     NaN         NaN           NaN          NaN
# 32274   3693468.0       7.0     NaN         NaN           NaN          NaN
#
#        의료비_지출_총금액  교통_지출_총금액  여가_지출_총금액  문화_지출_총금액  교육_지출_총금액  유흥_지출_총금액
# 30650         NaN        NaN        NaN        NaN        NaN        NaN
# 32274         NaN        NaN        NaN        NaN        NaN        NaN

# %%
# . 1. 데이터 삭제  
df_2_1 = df_1.dropna()

# %%
# . 2. 지리적으로 가까운곳(유클리디안 거리로)의 값을 사용

# %%
# . 2.1 df_1에서 null값을 가지고 있는 데이터 셋 가져오기

# null값인 데이터 보관을 위한 데이터 셋 생성 
df_2_2_1 = pd.DataFrame()
# 컬럼별로 null값인 데이터 셋 저장 
for col in df_1.columns[6:] : 
    q = df_1[col].isnull()
    tmp = df_1[q]
    df_2_2_1 = pd.concat([df_2_2_1, tmp], axis = 0)
    
# 전체컬럼 기준 종복인컬럼 삭제 
df_2_2_1 = df_2_2_1.drop_duplicates()

# %%
df_2_2_1.head()
# Out:
#       기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드             상권_코드_명  \
# 868      2021         4        A       골목상권  2110870     신림주공2단지(광신고등학교)
# 1112     2021         4        D       발달상권  2120025  롯데백화점(시청광장 지하쇼핑센터)
# 1222     2021         4        D       발달상권  2120137        문래역(문래로데오거리)
# 1352     2021         4        R       전통시장  2130025       삼익패션타운(남대문시장)
# 1425     2021         4        R       전통시장  2130113                신아타운
#
#       월_평균_소득_금액  소득_구간_코드       지출_총금액   식료품_지출_총금액  의류_신발_지출_총금액  \
# 868          NaN       NaN  525158961.0  182775990.0    56778514.0
# 1112         NaN       NaN   42776800.0    9753700.0     6378372.0
# 1222         NaN       NaN   63883830.0   12544623.0     8205981.0
# 1352         NaN       NaN  116229093.0   26285646.0    16688661.0
# 1425         NaN       NaN   90288396.0   19005665.0    12176197.0
#
#       생활용품_지출_총금액  의료비_지출_총금액   교통_지출_총금액   여가_지출_총금액   문화_지출_총금액   교육_지출_총금액  \
# 868    35000230.0  89076459.0  59792839.0  16010293.0  17283761.0  49388632.0
# 1112    3414290.0   4949780.0   8313272.0   3229160.0   1234068.0   3606108.0
# 1222    5474138.0   6336884.0  11460297.0   3785327.0   1725862.0  11882007.0
# 1352    9929826.0  13192368.0  22183227.0   8157681.0   3433797.0  11270217.0
# 1425    7310211.0   9891946.0  16641928.0   5750504.0   2467598.0  13379157.0
#
#        유흥_지출_총금액
# 868   19052243.0
# 1112   1898050.0
# 1222   2468711.0
# 1352   5087670.0
# 1425   3665190.0

# %%
# . 2.2 기준정보데이터셋을 이용하여 거리가 가까운 데이터 찾기 
ma= pd.read_csv('./data/서울시 우리마을가게 상권분석서비스(상권영역).csv', encoding='cp949')

# %%
# . 2.2 df_2_2_1 의 상권코드를 기준으로 행별 x,y좌표값 입력 
df_2_2_2 = pd.merge(df_2_2_1, ma[['상권_코드', '엑스좌표_값', '와이좌표_값']], on = ['상권_코드'], how='left')

# %%
# . '엑스좌표_값', '와이좌표_값' 에 null이 존재하는지 확인
df_2_2_2[['엑스좌표_값', '와이좌표_값']].isnull().sum()
# Out:
# 엑스좌표_값    0
# 와이좌표_값    0
# dtype: int64

# %%
# 거리를 구할 데이터 셋의 경우 df_2_2_2의 상권코드를 가지고 있는 데이터 제거 
ma_notnull = ma.drop(ma[ma['상권_코드'].isin(df_2_2_1['상권_코드'].unique())].index)

# %%
# 기준정보에는 데이터가 존재하나 소득소비 엑셀에 데이터가 없는경우가 있어 추가 전처리 진행 
ma_notnull = ma_notnull[ma_notnull['상권_코드'].isin(df_1['상권_코드'].unique())]

# %%
ma_notnull.reset_index(inplace=True,drop=True)

# %%
ma_notnull[ma_notnull['상권_코드']==2110878]
# Out:
#     기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명  엑스좌표_값  와이좌표_값  시군구_코드  \
# 86    202112        A       골목상권  2110878    미림여고  194062  440614   11620
#
#       행정동_코드  형태정보
# 86  11620745   NaN

# %%
ma_notnull[ma_notnull['상권_코드']==2110878]

# %%
# 가까운 상권코드 컬럼 초기화
df_2_2_2['가까운_상권_코드'] = 0

# %%
# df_2_2_2 을 기준으로 ma_notnull에 상권들과 거리상 가까운 곳을 저장 

for i in range(len(df_2_2_2)):
# for i in range(1):
    eu_dis = np.inf
    clos_sc = np.inf
    null_xy = (df_2_2_2.loc[i, '엑스좌표_값'], df_2_2_2.loc[i, '와이좌표_값'])
    for j in range(len(ma_notnull)):
        notnull_xy = (ma_notnull.loc[j, '엑스좌표_값'], ma_notnull.loc[j, '와이좌표_값'])


        if distance.euclidean(null_xy, notnull_xy) < eu_dis :
            eu_dis = distance.euclidean(null_xy, notnull_xy)
            clos_sc = ma_notnull.loc[j, '상권_코드']
            
    print("best result for distance : ", eu_dis, "best result for sc : ",  clos_sc)
    df_2_2_2.loc[i, '가까운_상권_코드'] = clos_sc
# Out:
# best result for distance :  584.9111043568929 best result for sc :  2110878
# best result for distance :  175.32826355154492 best result for sc :  1001492
# best result for distance :  227.29716232280595 best result for sc :  2120140
# best result for distance :  131.59027319676784 best result for sc :  2130024
# best result for distance :  305.20321099228295 best result for sc :  2130116
# best result for distance :  87.46427842267951 best result for sc :  2110431
# best result for distance :  44.94441010848846 best result for sc :  2130253
# best result for distance :  107.00467279516349 best result for sc :  2110884
# best result for distance :  306.71974178392884 best result for sc :  2120167
# best result for distance :  195.86219645454813 best result for sc :  2120216
# best result for distance :  584.9111043568929 best result for sc :  2110878
# best result for distance :  175.32826355154492 best result for sc :  1001492
# best result for distance :  227.29716232280595 best result for sc :  2120140
# best result for distance :  131.59027319676784 best result for sc :  2130024
# best result for distance :  305.20321099228295 best result for sc :  2130116
# best result for distance :  87.46427842267951 best result for sc :  2110431
# best result for distance :  44.94441010848846 best result for sc :  2130253
# best result for distance :  107.00467279516349 best result for sc :  2110884
# best result for distance :  306.71974178392884 best result for sc :  2120167
# best result for distance :  195.86219645454813 best result for sc :  2120216
# best result for distance :  584.9111043568929 best result for sc :  2110878
# best result for distance :  175.32826355154492 best result for sc :  1001492
# best result for distance :  227.29716232280595 best result for sc :  2120140
# best result for distance :  131.59027319676784 best result for sc :  2130024
# best result for distance :  305.20321099228295 best result for sc :  2130116
# best result for distance :  87.46427842267951 best result for sc :  2110431
# best result for distance :  44.94441010848846 best result for sc :  2130253
# best result for distance :  107.00467279516349 best result for sc :  2110884
# best result for distance :  306.71974178392884 best result for sc :  2120167
# best result for distance :  195.86219645454813 best result for sc :  2120216
# best result for distance :  584.9111043568929 best result for sc :  2110878
# best result for distance :  175.32826355154492 best result for sc :  1001492
# best result for distance :  227.29716232280595 best result for sc :  2120140
# best result for distance :  131.59027319676784 best result for sc :  2130024
# best result for distance :  305.20321099228295 best result for sc :  2130116
# best result for distance :  87.46427842267951 best result for sc :  2110431
# best result for distance :  44.94441010848846 best result for sc :  2130253
# best result for distance :  107.00467279516349 best result for sc :  2110884
# best result for distance :  306.71974178392884 best result for sc :  2120167
# best result for distance :  195.86219645454813 best result for sc :  2120216
# best result for distance :  296.7861182737495 best result for sc :  2110106
# best result for distance :  84.02380615040002 best result for sc :  2120107
# best result for distance :  162.88953311984167 best result for sc :  2120107
# best result for distance :  218.0 best result for sc :  2110606
# best result for distance :  328.5391909650963 best result for sc :  2120141
# best result for distance :  96.20810776644555 best result for sc :  2110861
# best result for distance :  106.96261028976434 best result for sc :  2130285
# best result for distance :  741.1187489194967 best result for sc :  2120188
# best result for distance :  807.4379233105168 best result for sc :  2120220
# best result for distance :  305.9444394003591 best result for sc :  2120222

# %%
df_clos = df_1.copy()
df_clos.columns = ['가까운_기준_년_코드', '가까운_기준_분기_코드', '가까운_상권_구분_코드', '가까운_상권_구분_코드_명', '가까운_상권_코드', '가까운_상권_코드_명',
       '가까운_월_평균_소득_금액', '가까운_소득_구간_코드', '가까운_지출_총금액', '가까운_식료품_지출_총금액', '가까운_의류_신발_지출_총금액',
       '가까운_생활용품_지출_총금액', '가까운_의료비_지출_총금액', '가까운_교통_지출_총금액', '가까운_여가_지출_총금액', '가까운_문화_지출_총금액',
       '가까운_교육_지출_총금액', '가까운_유흥_지출_총금액']

# %%
# . 기존데이터 셋(df_2_2_1) 과 merge 하여 결측치 보간 
df_2_2_3 = pd.merge(df_2_2_2, df_clos, how='left'
        , left_on = ['기준_년_코드', '기준_분기_코드', '가까운_상권_코드'], right_on = ['가까운_기준_년_코드', '가까운_기준_분기_코드', '가까운_상권_코드'])

# %%
df_2_2_3.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드             상권_코드_명  \
# 0     2021         4        A       골목상권  2110870     신림주공2단지(광신고등학교)
# 1     2021         4        D       발달상권  2120025  롯데백화점(시청광장 지하쇼핑센터)
# 2     2021         4        D       발달상권  2120137        문래역(문래로데오거리)
# 3     2021         4        R       전통시장  2130025       삼익패션타운(남대문시장)
# 4     2021         4        R       전통시장  2130113                신아타운
#
#    월_평균_소득_금액  소득_구간_코드       지출_총금액   식료품_지출_총금액  ...    가까운_지출_총금액  \
# 0         NaN       NaN  525158961.0  182775990.0  ...  1.009296e+09
# 1         NaN       NaN   42776800.0    9753700.0  ...  7.990605e+08
# 2         NaN       NaN   63883830.0   12544623.0  ...  7.991680e+06
# 3         NaN       NaN  116229093.0   26285646.0  ...  2.976414e+08
# 4         NaN       NaN   90288396.0   19005665.0  ...  1.936274e+08
#
#    가까운_식료품_지출_총금액  가까운_의류_신발_지출_총금액  가까운_생활용품_지출_총금액  가까운_의료비_지출_총금액  \
# 0     249519192.0       127104883.0       77649609.0     130056735.0
# 1     198543079.0       109338730.0       65537299.0     100540265.0
# 2       1866290.0          981223.0         653224.0        940436.0
# 3      73259710.0        41017287.0       24731465.0      36698125.0
# 4      41209289.0        26298345.0       15260766.0      21467594.0
#
#    가까운_교통_지출_총금액  가까운_여가_지출_총금액  가까운_문화_지출_총금액  가까운_교육_지출_총금액  가까운_유흥_지출_총금액
# 0    180714441.0     45217762.0     29220594.0    126416887.0     43395938.0
# 1    145153295.0     47266880.0     23816404.0     73392736.0     35471786.0
# 2      1394935.0       408388.0       232166.0      1217100.0       297918.0
# 3     54843651.0     17461649.0      8976211.0     27166810.0     13486502.0
# 4     35612871.0     12166321.0      5226380.0     28474651.0      7911146.0
#
# [5 rows x 38 columns]

# %%
# 컬럼 별 null값 입력 
df_2_2_4 = df_2_2_3.copy()

for i in df_2_2_4.columns[6:18]:
    col = i
    notnull_col = '가까운_'+i
    
    df_2_2_4[col] = np.where(df_2_2_4[col].isnull(), df_2_2_4[notnull_col], df_2_2_4[col])

# %%
df_2_2_4.iloc[:, :18].isnull().sum()
# Out:
# 기준_년_코드         0
# 기준_분기_코드        0
# 상권_구분_코드        0
# 상권_구분_코드_명      0
# 상권_코드           0
# 상권_코드_명         0
# 월_평균_소득_금액      0
# 소득_구간_코드        0
# 지출_총금액          0
# 식료품_지출_총금액      0
# 의류_신발_지출_총금액    0
# 생활용품_지출_총금액     0
# 의료비_지출_총금액      0
# 교통_지출_총금액       0
# 여가_지출_총금액       0
# 문화_지출_총금액       0
# 교육_지출_총금액       0
# 유흥_지출_총금액       0
# dtype: int64

# %%
df_2_2 = df_2_2_4.iloc[:, :18].copy()

# %% [markdown]
# # 1. 데이터 내 seasonality 제거

# %% [markdown]
#  계절성을 없애고 기준년, 상권구분, 상권코드, 서비스 업종 기반으로 분석하기 위해 데이터 전처리

# %% [markdown]
# '분기당_매출_금액' : 계절성을 없애기 위해 분기별 평균금액 사용
# 'xxx건수' : 비율 확인을 위해 분기 합계 수치 계산

# %%
df.shape

# %%
df_2 = df.groupby(['기준_년_코드','상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
       '서비스_업종_코드', '서비스_업종_코드_명']).mean()[['분기당_매출_금액']].reset_index()

# %%
df_2.head()

# %%
groupby_col = ['분기당_매출_건수','주중_매출_건수',
       '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
       '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
       '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
       '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
       '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
       '연령대_50_매출_건수', '연령대_60_이상_매출_건수', '점포수']

# %%
df_2[groupby_col] = df.groupby(['기준_년_코드','상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
       '서비스_업종_코드', '서비스_업종_코드_명']).sum()[groupby_col].reset_index().drop(columns = df.columns[[0,2,3,4,5,6,7]])

# %%
df_2.head()[['상권_코드','서비스_업종_코드', '분기당_매출_건수', '남성_매출_건수', '여성_매출_건수']]

# %%
# 원본데이터도 잘 맞지 않음...
# df.loc[(df['상권_코드']==1001496)&(df['서비스_업종_코드']=='CS300043'), ['상권_코드','서비스_업종_코드', '분기당_매출_건수', '남성_매출_건수', '여성_매출_건수']]

# %% [markdown]
# # 3. 파생변수 생성

# %% [markdown]
# . 아래 매출건수를 비율 변환  (ex > 남성매출건수/분기당매출건수)
#     ['분기당_매출_건수','남성_매출_건수', '여성_매출_건수',
#     '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
#      '연령대_50_매출_건수', '연령대_60_이상_매출_건수']

# %%
# df_food2 = df_food_1.copy()
df_3 = df_2.copy()

# %%
df_3.head()

# %%
case_col = ['남성_매출_건수', '여성_매출_건수',
    '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
     '연령대_50_매출_건수', '연령대_60_이상_매출_건수']
rate_col = ['남성_매출_건수_비율', '여성_매출_건수_비율',
    '연령대_10_매출_건수_비율', '연령대_20_매출_건수_비율', '연령대_30_매출_건수_비율', '연령대_40_매출_건수_비율',
     '연령대_50_매출_건수_비율', '연령대_60_이상_매출_건수_비율']

# %%
df_3[rate_col] = df_3[case_col].div(df_3['분기당_매출_건수'], axis=0)

# %%
df_3[['분기당_매출_건수', '남성_매출_건수', '여성_매출_건수', '남성_매출_건수_비율', '여성_매출_건수_비율']].head()
# 남성매출건수와 여성매출건수의 합이 전체 분기당 매출건수의 합과 일치하지 않음

# %%
df_3.to_csv('./data/1.추정매출_전처리완료.csv' , encoding='cp949')
